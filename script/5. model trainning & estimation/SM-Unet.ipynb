# %% [raw]
# I use the following code for a new conda environment to set up a gpu-basejupyter lab.
# conda install python==3.9
# pip install tensorflow-gpu==2.10.0
# conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
# conda install -c conda-forge cudatoolkit=10.0 cudnn=7.4.0
#
# method 2L
# Python 3.7: conda install tensorflow-gpu=2.3 tensorflow=2.3=mkl_py37h936c3e2_0
# keras == 2.3.1
# pip install patchify==0.2.2
# pip install classification-models-3D==1.0.2
# pip install efficientnet-3D==1.0.1
# pip install segmentation-models-3D==1.0.1

# %%
print("os module is part of Python standard library. Python version:", sys.version)
# Out:
# os module is part of Python standard library. Python version: 3.9.19 (main, Mar 21 2024, 17:21:27) [MSC v.1916 64 bit (AMD64)]

# %%
import tensorflow as tf
import keras
print(tf.test.is_built_with_cuda())
print(tf.__version__)
print(keras.__version__)

# Make sure the GPU is available.
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name == '':
    print('GPU device not found. TensorFlow is using CPU.')
else:
    print('Found GPU at: {}'.format(device_name))


print(tf.test.is_gpu_available())
tf.config.list_physical_devices('GPU')

import segmentation_models_3D as sm
from skimage import io
from patchify import patchify, unpatchify
import numpy as np
from matplotlib import pyplot as plt
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import file_utilities as fu
# Out:
# True
# 2.10.0
# 2.10.0
# Found GPU at: /device:GPU:0
# WARNING:tensorflow:From C:\Users\Ding-Yang\AppData\Local\Temp\ipykernel_17616\68065243.py:18: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# Segmentation Models: using `keras` framework.

# %%
import pkg_resources

def get_installed_packages_versions():
    installed_packages = pkg_resources.working_set
    packages_list = sorted(["%s==%s" % (i.key, i.version) for i in installed_packages])
    return packages_list

packages_versions = get_installed_packages_versions()
for package in packages_versions:
    print(package)
# Out:
# absl-py==2.1.0
# aggdraw==1.3.18.post0
# alabaster==0.7.16
# annotated-types==0.6.0
# anyio==4.2.0
# app-model==0.2.6
# appdirs==1.4.4
# archspec==0.2.3
# argon2-cffi-bindings==21.2.0
# argon2-cffi==21.3.0
# asttokens==2.0.5
# astunparse==1.6.3
# async-lru==2.0.4
# attrs==23.1.0
# babel==2.11.0
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==4.1.0
# boltons==24.0.0
# brotli==1.0.9
# build==1.2.1
# cachetools==5.3.3
# cachey==0.2.1
# certifi==2024.2.2
# cffi==1.16.0
# chardet==5.2.0
# charset-normalizer==2.0.4
# clang==5.0
# classification-models-3d==1.0.8
# click==8.1.7
# cloudpickle==3.0.0
# colorama==0.4.6
# comm==0.2.1
# conda-libmamba-solver==24.1.0
# conda-package-handling==2.2.0
# conda-package-streaming==0.9.0
# conda==24.3.0
# contourpy==1.2.1
# cycler==0.12.1
# dask==2024.4.2
# debugpy==1.6.7
# decorator==5.1.1
# defusedxml==0.7.1
# distro==1.9.0
# docstring-parser==0.16
# docutils==0.17.1
# efficientnet-3d==1.0.1
# exceptiongroup==1.2.0
# executing==0.8.3
# fastjsonschema==2.16.2
# flatbuffers==24.3.25
# fonttools==4.51.0
# freetype-py==2.4.0
# fsspec==2024.3.1
# gast==0.4.0
# google-auth-oauthlib==0.4.6
# google-auth==2.29.0
# google-pasta==0.2.0
# grpcio==1.62.1
# h5py==3.1.0
# heapdict==1.0.1
# hsluv==5.0.4
# idna==3.4
# imageio==2.34.0
# imagesize==1.4.1
# importlib-metadata==7.1.0
# importlib-resources==6.4.0
# in-n-out==0.2.1
# ipykernel==6.25.0
# ipython==8.15.0
# jedi==0.18.1
# jinja2==3.1.3
# joblib==1.4.0
# json5==0.9.6
# jsonpatch==1.33
# jsonpointer==2.4
# jsonschema-specifications==2023.7.1
# jsonschema==4.19.2
# jupyter-client==8.6.0
# jupyter-core==5.5.0
# jupyter-events==0.8.0
# jupyter-lsp==2.2.0
# jupyter-server-terminals==0.4.4
# jupyter-server==2.10.0
# jupyterlab-pygments==0.1.2
# jupyterlab-server==2.25.1
# jupyterlab==4.0.11
# keras-applications==1.0.8
# keras-preprocessing==1.1.2
# keras==2.10.0
# kiwisolver==1.4.5
# lazy-loader==0.4
# libclang==18.1.1
# libmambapy==1.5.8
# locket==1.0.0
# magicgui==0.8.2
# mamba==1.5.8
# markdown-it-py==3.0.0
# markdown==3.6
# markupsafe==2.1.5
# matplotlib-inline==0.1.6
# matplotlib==3.8.4
# mdurl==0.1.2
# menuinst==2.0.2
# mistune==2.0.4
# napari-console==0.0.9
# napari-plugin-engine==0.2.0
# napari-svg==0.1.10
# napari==0.4.19.post1
# nbclient==0.8.0
# nbconvert==7.10.0
# nbformat==5.9.2
# nest-asyncio==1.6.0
# networkx==3.2.1
# neuralplot==0.0.8
# notebook-shim==0.2.3
# notebook==7.0.8
# npe2==0.7.5
# numpy==1.26.4
# numpydoc==1.5.0
# oauthlib==3.2.2
# opt-einsum==3.3.0
# overrides==7.4.0
# packaging==23.2
# pandas==2.2.2
# pandocfilters==1.5.0
# parso==0.8.3
# partd==1.4.1
# patchify==0.2.2
# pickleshare==0.7.5
# pillow==10.3.0
# pint==0.23
# pip==23.3.1
# platformdirs==3.10.0
# pluggy==1.5.0
# pooch==1.8.1
# prometheus-client==0.14.1
# prompt-toolkit==3.0.43
# protobuf==3.19.6
# psutil==5.9.0
# psygnal==0.11.0
# pure-eval==0.2.2
# pyasn1-modules==0.4.0
# pyasn1==0.6.0
# pyconify==0.1.6
# pycosat==0.6.6
# pycparser==2.21
# pydantic-compat==0.1.2
# pydantic-core==2.18.1
# pydantic==2.7.0
# pygments==2.15.1
# pyopengl==3.1.7
# pyparsing==3.1.2
# pyproject-hooks==1.0.0
# pyqt5-qt5==5.15.2
# pyqt5-sip==12.13.0
# pyqt5==5.15.10
# pyside2==5.15.2.1
# pysocks==1.7.1
# python-dateutil==2.8.2
# python-json-logger==2.0.7
# pytz==2023.3.post1
# pywavelets==1.6.0
# pywin32==305.1
# pywinpty==2.0.10
# pyyaml==6.0.1
# pyzmq==25.1.2
# qtconsole==5.5.1
# qtpy==2.4.1
# referencing==0.30.2
# requests-oauthlib==2.0.0
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rich==13.7.1
# rpds-py==0.10.6
# rsa==4.9
# ruamel.yaml.clib==0.2.8
# ruamel.yaml==0.18.6
# scikit-image==0.22.0
# scikit-learn==1.4.2
# scipy==1.13.0
# segmentation-models-3d==1.0.1
# send2trash==1.8.2
# setuptools==68.2.2
# shellingham==1.5.4
# shiboken2==5.15.2.1
# six==1.15.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# soupsieve==2.5
# sphinx==4.5.0
# sphinxcontrib-applehelp==1.0.8
# sphinxcontrib-devhelp==1.0.6
# sphinxcontrib-htmlhelp==2.0.5
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.7
# sphinxcontrib-serializinghtml==1.1.10
# stack-data==0.2.0
# superqt==0.6.3
# tabulate==0.9.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorboard==2.10.1
# tensorflow-estimator==2.10.0
# tensorflow-io-gcs-filesystem==0.31.0
# tensorflow==2.10.0
# termcolor==1.1.0
# terminado==0.17.1
# tf-estimator-nightly==2.8.0.dev2021122109
# threadpoolctl==3.4.0
# tifffile==2024.2.12
# tinycss2==1.2.1
# tomli-w==1.0.0
# tomli==2.0.1
# toolz==0.12.1
# tornado==6.3.3
# tqdm==4.66.2
# traitlets==5.7.1
# typer==0.12.3
# typing-extensions==4.11.0
# tzdata==2024.1
# urllib3==2.1.0
# vispy==0.14.2
# visualkeras==0.0.2
# wcwidth==0.2.5
# webencodings==0.5.1
# websocket-client==0.58.0
# werkzeug==3.0.2
# wheel==0.41.2
# win-inet-pton==1.1.0
# wrapt==1.12.1
# zipp==3.18.1
# zstandard==0.22.0

# %%
import subprocess

def get_cuda_version():
    try:
        output = subprocess.check_output(['nvcc', '--version'])
        return output.decode('utf-8').strip()
    except FileNotFoundError:
        return "nvcc (CUDA) not found"

cuda_version = get_cuda_version()
print("CUDA Version:")
print(cuda_version)
# Out:
# CUDA Version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
import os

def get_cudnn_version():
    try:
        cudnn_header_path = "/usr/local/cuda/include/cudnn.h"
        if os.path.isfile(cudnn_header_path):
            with open(cudnn_header_path, 'r') as f:
                for line in f:
                    if '#define CUDNN_MAJOR' in line:
                        major_version = line.split()[-1]
                    elif '#define CUDNN_MINOR' in line:
                        minor_version = line.split()[-1]
                    elif '#define CUDNN_PATCHLEVEL' in line:
                        patch_version = line.split()[-1]
                return f"cuDNN Version: {major_version}.{minor_version}.{patch_version}"
        else:
            return "cuDNN header file not found"
    except Exception as e:
        return str(e)

cudnn_version = get_cudnn_version()
print(cudnn_version)
# Out:
# cuDNN header file not found

# %%
# Get the file path
file_path = fu.choose_file()
image = io.imread(file_path)

# Get the file path
file_path = fu.choose_file()
mask = io.imread(file_path)
#mask_reduce = mask[0:16,:,:]
#mask_patches = patchify(mask, (64, 64, 64), step=64)
# Out:
# Selected File: C:/Users/Ding-Yang/Desktop/internship/Try don't merge/better images/Unet/Preprocess image/section 2 740 TexRed Dextrans 3K dil 2 30 min CertnL 11.05.23/rm_bg.tiff
# Selected File: C:/Users/Ding-Yang/Desktop/internship/Try don't merge/better images/Unet/GT/section 2 740 TexRed Dextrans 3K dil 2 30 min CertnL 11.05.23/label_wih_border_mask_3.tif

# %%
import os
import glob
import tifffile

def read_augmentation_images(original_image_path):
    # Get the current directory
    current_directory = os.getcwd()
    
    # Check if the 'Augmentation' directory exists
    augmentation_directory = os.path.join(current_directory, "Augmentation")
    if os.path.exists(augmentation_directory):
        # Get the directory path of the file
        file_directory = os.path.dirname(original_image_path)
        
        # Get the name of the last folder
        last_folder_name = os.path.basename(file_directory)

        # Check if the last_folder_name directory exists
        image_directory = os.path.join(augmentation_directory, last_folder_name, "image")
        mask_directory = os.path.join(augmentation_directory, last_folder_name, "mask")
        
        if os.path.exists(image_directory) and os.path.exists(mask_directory):
            # Read image files
            image_files = glob.glob(os.path.join(image_directory, "*.tif"))
            images = {os.path.splitext(os.path.basename(image_file))[0]: tifffile.imread(image_file) for image_file in image_files}

            # Read mask files
            mask_files = glob.glob(os.path.join(mask_directory, "*.tif"))
            masks = {os.path.splitext(os.path.basename(mask_file))[0]: tifffile.imread(mask_file) for mask_file in mask_files}
            
            if images and masks:
                print(f"Read {len(images)} images and {len(masks)} masks")
            else:
                print("Failed to read images and masks")
            return {"image": images, "mask": masks}
        else:
            print("Image or mask directory does not exist")
            return None
    else:
        print("Augmentation directory does not exist")
        return None

# Usage
result_dict = read_augmentation_images(file_path)
# Out:
# Read 1 images and 1 masks

# %%
def check_shapes(image_dict):
    # Initialize lists to store shapes and their corresponding keys
    image_shapes = []
    mask_shapes = []
    image_keys = []
    mask_keys = []

    # Iterate over the items in the dictionary
    for key, sub_dict in image_dict.items():
        for sub_key, value in sub_dict.items():
            if 'image' in sub_key.lower():
                image_shapes.append(value.shape)
                image_keys.append(sub_key)
            elif 'mask' in sub_key.lower():
                mask_shapes.append(value.shape)
                mask_keys.append(sub_key)

    # Check if all image shapes are the same
    same_image_shapes = all(shape == image_shapes[0] for shape in image_shapes)

    # Check if all mask shapes are the same
    same_mask_shapes = all(shape == mask_shapes[0] for shape in mask_shapes)

    if same_image_shapes:
        print("All images have the same shape:", image_shapes[0])
    else:
        print("Images have different shapes. All images must have the same shape")
        for i, shape in enumerate(image_shapes):
            if shape != image_shapes[0]:
                raise ValueError(f"Image {image_keys[i]} has shape:", shape)

    if same_mask_shapes:
        print("All masks have the same shape:", mask_shapes[0])
    else:
        print("Masks have different shapes. All masks must have the same shape")
        for i, shape in enumerate(mask_shapes):
            if shape != mask_shapes[0]:
                raise ValueError(f"Mask {mask_keys[i]} has shape:", shape)

    if image_shapes[0] == mask_shapes[0]:
        print("All images and masks have same shapes", mask_shapes[0])
        return image_shapes[0]
    else:
        raise ValueError("Images and masks have different shapes")

# Usage
image_shape = check_shapes(result_dict)
# Out:
# All images have the same shape: (17, 1024, 1024)
# All masks have the same shape: (17, 1024, 1024)
# All images and masks have same shapes (17, 1024, 1024)

# %%
image_keys = list(result_dict['image'].keys())
mask_keys = list(result_dict['mask'].keys())

# 找到匹配的键对
matched_pairs = [(image_key, mask_key) for image_key in image_keys for mask_key in mask_keys if image_key.split(' ')[0] == mask_key.split(' ')[0]]

# 打印匹配的键对
for i, (image_key, mask_key) in enumerate(matched_pairs):
    print("image:", i)
    print("Image key:", image_key)
    print("Mask key:", mask_key)

    print()
# Out:
# image: 0
# Image key: RandomGamma_RandomFlip_transpose 0 Image
# Mask key: RandomGamma_RandomFlip_transpose 0 Mask

# %% [markdown]
# # doubke the size

# %%
import numpy as np
import math

def adjust_image_size(result_dict, z_target = None):
    # Get the shape of the images
    image_shapes = check_shapes(result_dict)
    if len(result_dict['image']) != len(result_dict['mask']):
        raise ValueError("Your image and mask couldn't match")

    # Get the shape of the images
    oz, ox, oy = image_shapes
    if z_target == None:
        z_target = round(oz / 32) * 32
        print(f"Adjusting your result_dict image shape from {image_shapes} into {(z_target, ox, oy)}...")
    else:        
        # Check if z_target is divisible by 32
        if z_target % 32 != 0:
            raise ValueError("z_target must be divisible by 32")

    # make adjusted_result dic
    adjusted_result = {'image': {}, 'mask': {}}
    num_images = len(result_dict['image'])
    num_adjusted_images = len(result_dict['image'])
    for i in range(num_adjusted_images):
        adjusted_image_key = f"image {i+1}"
        adjusted_mask_key = f"mask {i+1}"
        adjusted_result['image'][adjusted_image_key] = np.zeros((z_target, ox, oy), dtype=result_dict['image'][list(result_dict['image'].keys())[i]].dtype)
        adjusted_result['mask'][adjusted_mask_key] = np.zeros((z_target, ox, oy), dtype=result_dict['mask'][list(result_dict['mask'].keys())[i]].dtype)

    # Check if z_target is higher or lower than the current z
    if oz > z_target:
        # Higher, crop the images
        image_keys = list(result_dict['image'].keys())
        mask_keys = list(result_dict['mask'].keys())
        
        # 找到匹配的键对
        matched_pairs = [(image_key, mask_key) for image_key in image_keys for mask_key in mask_keys if image_key.split(' ')[0] == mask_key.split(' ')[0]]
        
        # 打印匹配的键对count, value in enumerate(values
        for i, (image_key, mask_key) in enumerate(matched_pairs):
            key_adjust_image = list(adjusted_result['image'].keys())[i]
            adjusted_result["image"][key_adjust_image] = np.copy(result_dict['image'][image_key][0:z_target])

            key_adjust_mask = list(adjusted_result['mask'].keys())[i]
            adjusted_result["mask"][key_adjust_mask] = np.copy(result_dict['mask'][mask_key][0:z_target])


    elif oz < z_target:
        # Lower, pad the images
        # Higher, crop the images
        image_keys = list(result_dict['image'].keys())
        mask_keys = list(result_dict['mask'].keys())
        
        # 找到匹配的键对
        matched_pairs = [(image_key, mask_key) for image_key in image_keys for mask_key in mask_keys if image_key.split(' ')[0] == mask_key.split(' ')[0]]
        
        # 打印匹配的键对count, value in enumerate(values
        for i, (image_key, mask_key) in enumerate(matched_pairs):
            key_adjust_image = list(adjusted_result['image'].keys())[i]
            adjusted_result["image"][key_adjust_image][0:oz] = np.copy(result_dict['image'][image_key])
            adjusted_result["image"][key_adjust_image][oz:z_target] = np.copy(result_dict['image'][image_key][0:z_target - oz])


            key_adjust_mask = list(adjusted_result['mask'].keys())[i]
            adjusted_result["mask"][key_adjust_mask][0:oz] = np.copy(result_dict['mask'][mask_key])
            adjusted_result["mask"][key_adjust_mask][oz:z_target] = np.copy(result_dict['mask'][mask_key][0:z_target - oz])
    else:
        print("Your z_target has the same size as the original of the image. The images do not change.")
        adjusted_result = result_dict
    print("Finish!")
    return adjusted_result

# Usage
adjusted_result = adjust_image_size(result_dict)
# Out:
# All images have the same shape: (17, 1024, 1024)
# All masks have the same shape: (17, 1024, 1024)
# All images and masks have same shapes (17, 1024, 1024)
# Adjusting your result_dict image shape from (17, 1024, 1024) into (32, 1024, 1024)...
# Finish!

# %%
adjusted_result['image']['image 1'].shape
# Out:
# (32, 1024, 1024)

# %%
z, _, _ = adjusted_result['image']['image 1'].shape
reszie_image = np.zeros((z, 1024, 1024))
reszie_mask = np.zeros((z, 1024, 1024))

if image.shape[0] <= z:
    reszie_image[0:image.shape[0]] = image
    reszie_image[image.shape[0]:z] = image[0:z-image.shape[0]]
    reszie_mask[0:image.shape[0]] = mask
    reszie_mask[image.shape[0]:z] = mask[0:z-mask.shape[0]]
else:
    reszie_image = image[0:z]
    reszie_mask = mask[0:z]

image = reszie_image

mask = reszie_mask

# %%
from patchify import patchify, unpatchify
img_patches = patchify(image, (32, 64, 64), step=64)  #Step=64 for 64 patches means no overlap
mask_patches = patchify(mask, (32, 64, 64), step=64)  
print(img_patches.shape,mask_patches.shape)

image_dataset = np.reshape(img_patches, (-1, img_patches.shape[3], img_patches.shape[4], img_patches.shape[5]))
mask_dataset = np.reshape(mask_patches, (-1, mask_patches.shape[3], mask_patches.shape[4], mask_patches.shape[5]))

print(image_dataset.shape)  # n_patches, x, y, z
# Out:
# (1, 16, 16, 32, 64, 64) (1, 16, 16, 32, 64, 64)
# (256, 32, 64, 64)

# %%
image_keys = list(adjusted_result['image'].keys())
mask_keys = list(adjusted_result['mask'].keys())
matched_pairs = [(image_keys[i], mask_keys[i]) for i in range(min(len(image_keys), len(mask_keys)))]
for i, (image_key, mask_key) in enumerate(matched_pairs):
    print(f"patching image {i+1}")
    img_patches = patchify(adjusted_result['image'][image_key], (32, 64, 64), step=64)  #Step=64 for 64 patches means no overlap
    mask_patches = patchify(adjusted_result['mask'][mask_key], (32, 64, 64), step=64)  
    input_img = np.reshape(img_patches, (-1, img_patches.shape[3], img_patches.shape[4], img_patches.shape[5]))
    input_mask = np.reshape(mask_patches, (-1, mask_patches.shape[3], mask_patches.shape[4], mask_patches.shape[5]))
    image_dataset = np.concatenate([image_dataset, input_img], axis=0)
    mask_dataset = np.concatenate([mask_dataset, input_mask], axis=0)
# Out:
# patching image 1

# %% [markdown]
# # Two image data

# %%
image_dataset.shape
# Out:
# (512, 32, 64, 64)

# %%
image_dataset_1 = np.copy(image_dataset)
mask_dataset_1 = np.copy(mask_dataset)

# %%
image_dataset = np.concatenate(image_dataset_1, axis=1)
mask_dataset =np.concatenate(mask_dataset_1, axis=0)
image_dataset.shape
# Out:
# (32, 32768, 64)

# %%
# 将两个数组沿着第一个轴合并
merged_image = np.concatenate((image_dataset_1, image_dataset), axis=0)
merged_mask = np.concatenate((mask_dataset_1, mask_dataset), axis=0)

# 打印合并后的数组形状
print(merged_image.shape)
# Out:
# (1024, 32, 64, 64)

# %%
image_dataset = np.copy(merged_image)
mask_dataset =np.copy(merged_mask)
image_dataset.shape
# Out:
# (1024, 32, 64, 64)

# %% [markdown]
# # merge 2 image into 1

# %%
double_the_size_image = np.zeros((32, 1024, 1024),  dtype= image.dtype)
double_the_size_image[0:17] = image
double_the_size_image[17:32] = result_dict['image'][matched_pairs[0][0]][:15]
image = double_the_size_image


double_the_size_mask = np.zeros((32, 1024, 1024), dtype= image.dtype)
double_the_size_mask[0:17] = mask
double_the_size_mask[17:32] = result_dict['mask'][matched_pairs[0][1]][:15]
mask = double_the_size_mask

# %%
from patchify import patchify, unpatchify
img_patches = patchify(image, (32, 64, 64), step=64)  #Step=64 for 64 patches means no overlap
mask_patches = patchify(mask, (32, 64, 64), step=64)  
print(img_patches.shape,mask_patches.shape)

image_dataset = np.reshape(img_patches, (-1, img_patches.shape[3], img_patches.shape[4], img_patches.shape[5]))
mask_dataset = np.reshape(mask_patches, (-1, mask_patches.shape[3], mask_patches.shape[4], mask_patches.shape[5]))

print(image_dataset.shape)  # n_patches, x, y, z

# %%
for i in range(1, len(result_dict['image']),2):
    double_the_size_image = np.zeros((32, 1024, 1024),  dtype= image.dtype)
    double_the_size_image[0:17] = result_dict['image'][matched_pairs[i][0]]
    double_the_size_image[17:32] = result_dict['image'][matched_pairs[i+1][0]][:15]
    image = double_the_size_image
    
    
    double_the_size_mask = np.zeros((32, 1024, 1024), dtype= image.dtype)
    double_the_size_mask[0:17] = result_dict['mask'][matched_pairs[i][1]]
    double_the_size_mask[17:32] = result_dict['mask'][matched_pairs[i+1][1]][:15]
    mask = double_the_size_mask

    print(f"patching image {i+1}")
    img_patches = patchify(image, (32, 64, 64), step=64)  #Step=64 for 64 patches means no overlap
    mask_patches = patchify(mask, (32, 64, 64), step=64)  
    
    input_img = np.reshape(img_patches, (-1, img_patches.shape[3], img_patches.shape[4], img_patches.shape[5]))
    input_mask = np.reshape(mask_patches, (-1, mask_patches.shape[3], mask_patches.shape[4], mask_patches.shape[5]))
    image_dataset = np.concatenate([image_dataset, input_img], axis=0)
    mask_dataset = np.concatenate([mask_dataset, input_mask], axis=0)

# %% [markdown]
# # Patchify

# %%
#Sanity check, view few mages
import random
import numpy as np
print(image_dataset.shape, mask_dataset.shape)
image_number = random.randint(0, len(image_dataset))
print(image_number)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number,:,:,28])
plt.subplot(122)
plt.imshow(mask_dataset[image_number,:,:,28])
plt.show()
# Out:
# (1024, 32, 64, 64) (1024, 32, 64, 64)
# 213

# %%
mask_dataset = mask_dataset.astype(np.uint8)
np.unique(mask_dataset)
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
image_dataset.shape
# Out:
# (1024, 32, 64, 64)

# %%
train_img = np.stack((image_dataset,)*3, axis=-1)
train_mask = np.expand_dims(mask_dataset, axis=-1)

# %%
import numpy as np

# 創建一個NumPy陣列

# 儲存陣列
np.save('./train_img.npy', train_img)
np.save('./train_mask.npy', train_mask)

# %%
n_classes=3# background, border, axons
from keras.utils import to_categorical

train_mask_cat = to_categorical(train_mask, num_classes=n_classes)


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_img, train_mask_cat, test_size = 0.1, random_state = 0)
np.save('./X_train.npy', X_train)
np.save('./X_test.npy', X_test)
np.save('./y_train.npy', y_train)
np.save('./y_test.npy', y_test)

# %%
import tensorflow as tf
import keras
print(tf.test.is_built_with_cuda())
print(tf.__version__)
print(keras.__version__)

# Make sure the GPU is available.
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name == '':
    print('GPU device not found. TensorFlow is using CPU.')
else:
    print('Found GPU at: {}'.format(device_name))


print(tf.test.is_gpu_available())
tf.config.list_physical_devices('GPU')

import segmentation_models_3D as sm
metrics = [sm.metrics.IOUScore(threshold=0.5)]
from skimage import io
from patchify import patchify, unpatchify
import numpy as np
from matplotlib import pyplot as plt
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import file_utilities as fu
# Out:
# True
# 2.10.0
# 2.10.0
# Found GPU at: /device:GPU:0
# WARNING:tensorflow:From C:\Users\Ding-Yang\AppData\Local\Temp\ipykernel_42200\68065243.py:18: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# Segmentation Models: using `keras` framework.

# %%
import numpy as np
train_img = np.load('./train_img.npy')
train_mask = np.load('./train_mask.npy')

train_mask.shape
# Out:
# (1024, 32, 64, 64, 1)

# %%
#Sanity check, view few mages
import random
import numpy as np
print(train_img.shape, train_mask.shape)
image_number = random.randint(0, len(train_img))
print(image_number)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(train_img[image_number,:,:,28,1])
plt.subplot(122)
plt.imshow(train_mask[image_number,:,:,28,0])
plt.show()
# Out:
# (1024, 32, 64, 64, 3) (1024, 32, 64, 64, 1)
# 795

# %%
X_train = np.load('./X_train.npy')
X_test = np.load('./X_test.npy')
y_train = np.load('./y_train.npy')
y_test = np.load('./y_test.npy')

# %%
#Sanity check, view few mages
import random
import numpy as np
print(X_train.shape, y_train.shape)
image_number = random.randint(0, len(X_train))
print(image_number)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number,:,:,28,1])
plt.subplot(122)
plt.imshow(y_train[image_number,:,:,28,0])
plt.show()
# Out:
# (921, 32, 64, 64, 3) (921, 32, 64, 64, 3)
# 198

# %%
#Define parameters for our model.

encoder_weights = 'imagenet'
BACKBONE = 'vgg16'  #Try vgg16, efficientnetb7, inceptionv3, resnet50
activation = 'softmax'
n_classes = 3
channels=3

LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([0.333, 0.333, 0.333])) #优点：对于不平衡的数据集和像素级别的分割任务效果较好，能够更好地处理类别间的不平衡。缺点：对噪声敏感，容易受到边缘效应的影响。
focal_loss = sm.losses.CategoricalFocalLoss()#优点：能够解决类别不平衡问题，通过调节alpha和gamma参数可以进一步调整损失函数的重点。缺点：需要调节额外的参数，可能需要进行一定的调参工作。
#jaccard_loss = sm.losses.JaccardLoss() #优点：度量了预测和标签之间的相似度，对于不平衡的数据集效果较好。缺点：对于像素级别的分割任务可能存在不连续性，需要额外处理。

total_loss = dice_loss + (1 * focal_loss)


# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5)]

# %%
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
#Preprocess input data - otherwise you end up with garbage resutls 
# and potentially model that does not converge.
X_train_prep = preprocess_input(X_train)
X_test_prep = preprocess_input(X_test)

# %%
X_train_prep.shape
# Out:
# (604, 32, 64, 64, 3)

# %%
#Define the model. Here we use Unet but we can also use other model architectures from the library.
model = sm.Unet(BACKBONE, classes=n_classes, 
                input_shape=(32, 64, 64, channels), 
                encoder_weights=encoder_weights,
                activation='softmax')

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping

#early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights = False)
model_checkpoint = ModelCheckpoint('./best_model.h5', monitor='val_loss', save_best_only=True)

callbacks=[#early_stopping,
           model_checkpoint,
                  CSVLogger('./history_au.csv'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)
          ]

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 64, 64,  0           []
#                                  3)]
#
#  block1_conv1 (Conv3D)          (None, 32, 64, 64,   5248        ['input_1[0][0]']
#                                 64)
#
#  block1_conv2 (Conv3D)          (None, 32, 64, 64,   110656      ['block1_conv1[0][0]']
#                                 64)
#
#  block1_pool (MaxPooling3D)     (None, 16, 32, 32,   0           ['block1_conv2[0][0]']
#                                 64)
#
#  block2_conv1 (Conv3D)          (None, 16, 32, 32,   221312      ['block1_pool[0][0]']
#                                 128)
#
#  block2_conv2 (Conv3D)          (None, 16, 32, 32,   442496      ['block2_conv1[0][0]']
#                                 128)
#
#  block2_pool (MaxPooling3D)     (None, 8, 16, 16, 1  0           ['block2_conv2[0][0]']
#                                 28)
#
#  block3_conv1 (Conv3D)          (None, 8, 16, 16, 2  884992      ['block2_pool[0][0]']
#                                 56)
#
#  block3_conv2 (Conv3D)          (None, 8, 16, 16, 2  1769728     ['block3_conv1[0][0]']
#                                 56)
#
#  block3_conv3 (Conv3D)          (None, 8, 16, 16, 2  1769728     ['block3_conv2[0][0]']
#                                 56)
#
#  block3_pool (MaxPooling3D)     (None, 4, 8, 8, 256  0           ['block3_conv3[0][0]']
#                                 )
#
#  block4_conv1 (Conv3D)          (None, 4, 8, 8, 512  3539456     ['block3_pool[0][0]']
#                                 )
#
#  block4_conv2 (Conv3D)          (None, 4, 8, 8, 512  7078400     ['block4_conv1[0][0]']
#                                 )
#
#  block4_conv3 (Conv3D)          (None, 4, 8, 8, 512  7078400     ['block4_conv2[0][0]']
#                                 )
#
#  block4_pool (MaxPooling3D)     (None, 2, 4, 4, 512  0           ['block4_conv3[0][0]']
#                                 )
#
#  block5_conv1 (Conv3D)          (None, 2, 4, 4, 512  7078400     ['block4_pool[0][0]']
#                                 )
#
#  block5_conv2 (Conv3D)          (None, 2, 4, 4, 512  7078400     ['block5_conv1[0][0]']
#                                 )
#
#  block5_conv3 (Conv3D)          (None, 2, 4, 4, 512  7078400     ['block5_conv2[0][0]']
#                                 )
#
#  block5_pool (MaxPooling3D)     (None, 1, 2, 2, 512  0           ['block5_conv3[0][0]']
#                                 )
#
#  center_block1_conv (Conv3D)    (None, 1, 2, 2, 512  7077888     ['block5_pool[0][0]']
#                                 )
#
#  center_block1_bn (BatchNormali  (None, 1, 2, 2, 512  2048       ['center_block1_conv[0][0]']
#  zation)                        )
#
#  center_block1_relu (Activation  (None, 1, 2, 2, 512  0          ['center_block1_bn[0][0]']
#  )                              )
#
#  center_block2_conv (Conv3D)    (None, 1, 2, 2, 512  7077888     ['center_block1_relu[0][0]']
#                                 )
#
#  center_block2_bn (BatchNormali  (None, 1, 2, 2, 512  2048       ['center_block2_conv[0][0]']
#  zation)                        )
#
#  center_block2_relu (Activation  (None, 1, 2, 2, 512  0          ['center_block2_bn[0][0]']
#  )                              )
#
#  decoder_stage0_upsampling (UpS  (None, 2, 4, 4, 512  0          ['center_block2_relu[0][0]']
#  ampling3D)                     )
#
#  decoder_stage0_concat (Concate  (None, 2, 4, 4, 102  0          ['decoder_stage0_upsampling[0][0]
#  nate)                          4)                               ',
#                                                                   'block5_conv3[0][0]']
#
#  decoder_stage0a_conv (Conv3D)  (None, 2, 4, 4, 256  7077888     ['decoder_stage0_concat[0][0]']
#                                 )
#
#  decoder_stage0a_bn (BatchNorma  (None, 2, 4, 4, 256  1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage0a_relu (Activati  (None, 2, 4, 4, 256  0          ['decoder_stage0a_bn[0][0]']
#  on)                            )
#
#  decoder_stage0b_conv (Conv3D)  (None, 2, 4, 4, 256  1769472     ['decoder_stage0a_relu[0][0]']
#                                 )
#
#  decoder_stage0b_bn (BatchNorma  (None, 2, 4, 4, 256  1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage0b_relu (Activati  (None, 2, 4, 4, 256  0          ['decoder_stage0b_bn[0][0]']
#  on)                            )
#
#  decoder_stage1_upsampling (UpS  (None, 4, 8, 8, 256  0          ['decoder_stage0b_relu[0][0]']
#  ampling3D)                     )
#
#  decoder_stage1_concat (Concate  (None, 4, 8, 8, 768  0          ['decoder_stage1_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'block4_conv3[0][0]']
#
#  decoder_stage1a_conv (Conv3D)  (None, 4, 8, 8, 128  2654208     ['decoder_stage1_concat[0][0]']
#                                 )
#
#  decoder_stage1a_bn (BatchNorma  (None, 4, 8, 8, 128  512        ['decoder_stage1a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage1a_relu (Activati  (None, 4, 8, 8, 128  0          ['decoder_stage1a_bn[0][0]']
#  on)                            )
#
#  decoder_stage1b_conv (Conv3D)  (None, 4, 8, 8, 128  442368      ['decoder_stage1a_relu[0][0]']
#                                 )
#
#  decoder_stage1b_bn (BatchNorma  (None, 4, 8, 8, 128  512        ['decoder_stage1b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage1b_relu (Activati  (None, 4, 8, 8, 128  0          ['decoder_stage1b_bn[0][0]']
#  on)                            )
#
#  decoder_stage2_upsampling (UpS  (None, 8, 16, 16, 1  0          ['decoder_stage1b_relu[0][0]']
#  ampling3D)                     28)
#
#  decoder_stage2_concat (Concate  (None, 8, 16, 16, 3  0          ['decoder_stage2_upsampling[0][0]
#  nate)                          84)                              ',
#                                                                   'block3_conv3[0][0]']
#
#  decoder_stage2a_conv (Conv3D)  (None, 8, 16, 16, 6  663552      ['decoder_stage2_concat[0][0]']
#                                 4)
#
#  decoder_stage2a_bn (BatchNorma  (None, 8, 16, 16, 6  256        ['decoder_stage2a_conv[0][0]']
#  lization)                      4)
#
#  decoder_stage2a_relu (Activati  (None, 8, 16, 16, 6  0          ['decoder_stage2a_bn[0][0]']
#  on)                            4)
#
#  decoder_stage2b_conv (Conv3D)  (None, 8, 16, 16, 6  110592      ['decoder_stage2a_relu[0][0]']
#                                 4)
#
#  decoder_stage2b_bn (BatchNorma  (None, 8, 16, 16, 6  256        ['decoder_stage2b_conv[0][0]']
#  lization)                      4)
#
#  decoder_stage2b_relu (Activati  (None, 8, 16, 16, 6  0          ['decoder_stage2b_bn[0][0]']
#  on)                            4)
#
#  decoder_stage3_upsampling (UpS  (None, 16, 32, 32,   0          ['decoder_stage2b_relu[0][0]']
#  ampling3D)                     64)
#
#  decoder_stage3_concat (Concate  (None, 16, 32, 32,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv3D)  (None, 16, 32, 32,   165888      ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, 16, 32, 32,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, 16, 32, 32,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv3D)  (None, 16, 32, 32,   27648       ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, 16, 32, 32,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, 16, 32, 32,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, 32, 64, 64,   0          ['decoder_stage3b_relu[0][0]']
#  ampling3D)                     32)
#
#  decoder_stage4a_conv (Conv3D)  (None, 32, 64, 64,   13824       ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 32, 64, 64,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, 32, 64, 64,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv3D)  (None, 32, 64, 64,   6912        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, 32, 64, 64,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, 32, 64, 64,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv3D)            (None, 32, 64, 64,   1299        ['decoder_stage4b_relu[0][0]']
#                                 3)
#
#  softmax (Activation)           (None, 32, 64, 64,   0           ['final_conv[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 71,233,107
# Trainable params: 71,229,075
# Non-trainable params: 4,032
# __________________________________________________________________________________________________
# None

# %%
#Fit the model
history=model.fit(X_train_prep, 
                  y_train,
                  batch_size=2, 
                  epochs=500,
                  validation_data=(X_test_prep,y_test),
                  callbacks=callbacks)
# Out:
# Epoch 1/500
# 461/461 [==============================] - 61s 124ms/step - loss: 1.4380 - iou_score: 0.4510 - val_loss: 1.4477 - val_iou_score: 0.5941 - lr: 1.0000e-04
# Epoch 2/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.3280 - iou_score: 0.5257 - val_loss: 1.3752 - val_iou_score: 0.6021 - lr: 1.0000e-04
# Epoch 3/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2982 - iou_score: 0.5542 - val_loss: 1.4189 - val_iou_score: 0.5517 - lr: 1.0000e-04
# Epoch 4/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2747 - iou_score: 0.5835 - val_loss: 2.0110 - val_iou_score: 0.1235 - lr: 1.0000e-04
# Epoch 5/500
# 461/461 [==============================] - 56s 121ms/step - loss: 1.2616 - iou_score: 0.5780 - val_loss: 1.3263 - val_iou_score: 0.6410 - lr: 1.0000e-04
# Epoch 6/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2586 - iou_score: 0.5851 - val_loss: 1.3369 - val_iou_score: 0.6263 - lr: 1.0000e-04
# Epoch 7/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2489 - iou_score: 0.5949 - val_loss: 1.3385 - val_iou_score: 0.6366 - lr: 1.0000e-04
# Epoch 8/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2545 - iou_score: 0.5895 - val_loss: 1.8482 - val_iou_score: 0.2276 - lr: 1.0000e-04
# Epoch 9/500
# 461/461 [==============================] - 56s 121ms/step - loss: 1.2365 - iou_score: 0.6117 - val_loss: 1.3025 - val_iou_score: 0.6587 - lr: 1.0000e-04
# Epoch 10/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2312 - iou_score: 0.6133 - val_loss: 1.3458 - val_iou_score: 0.6323 - lr: 1.0000e-04
# Epoch 11/500
# 461/461 [==============================] - 56s 120ms/step - loss: 1.2321 - iou_score: 0.6184 - val_loss: 1.2994 - val_iou_score: 0.6512 - lr: 1.0000e-04
# Epoch 12/500
# 461/461 [==============================] - 56s 120ms/step - loss: 1.2281 - iou_score: 0.6123 - val_loss: 1.2856 - val_iou_score: 0.6708 - lr: 1.0000e-04
# Epoch 13/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2230 - iou_score: 0.6129 - val_loss: 1.2984 - val_iou_score: 0.6571 - lr: 1.0000e-04
# Epoch 14/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.2228 - iou_score: 0.6155 - val_loss: 1.2820 - val_iou_score: 0.6731 - lr: 1.0000e-04
# Epoch 15/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2223 - iou_score: 0.6168 - val_loss: 2.6741 - val_iou_score: 0.0340 - lr: 1.0000e-04
# Epoch 16/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2083 - iou_score: 0.6287 - val_loss: 1.5491 - val_iou_score: 0.3782 - lr: 1.0000e-04
# Epoch 17/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.2118 - iou_score: 0.6228 - val_loss: 1.3337 - val_iou_score: 0.6262 - lr: 1.0000e-04
# Epoch 18/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2059 - iou_score: 0.6262 - val_loss: 1.2831 - val_iou_score: 0.6724 - lr: 1.0000e-04
# Epoch 19/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.2155 - iou_score: 0.6208 - val_loss: 1.2764 - val_iou_score: 0.6648 - lr: 1.0000e-04
# Epoch 20/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.2027 - iou_score: 0.6327 - val_loss: 1.3063 - val_iou_score: 0.6483 - lr: 1.0000e-04
# Epoch 21/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1965 - iou_score: 0.6398 - val_loss: 1.3504 - val_iou_score: 0.6171 - lr: 1.0000e-04
# Epoch 22/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.2040 - iou_score: 0.6389 - val_loss: 1.4665 - val_iou_score: 0.4971 - lr: 1.0000e-04
# Epoch 23/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1986 - iou_score: 0.6264 - val_loss: 1.3361 - val_iou_score: 0.6340 - lr: 1.0000e-04
# Epoch 24/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1987 - iou_score: 0.6349 - val_loss: 1.3045 - val_iou_score: 0.6576 - lr: 1.0000e-04
# Epoch 25/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1857 - iou_score: 0.6514 - val_loss: 1.3576 - val_iou_score: 0.6243 - lr: 1.0000e-04
# Epoch 26/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1848 - iou_score: 0.6530 - val_loss: 1.2928 - val_iou_score: 0.6645 - lr: 1.0000e-04
# Epoch 27/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1910 - iou_score: 0.6374 - val_loss: 1.2981 - val_iou_score: 0.6680 - lr: 1.0000e-04
# Epoch 28/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1785 - iou_score: 0.6515 - val_loss: 1.3082 - val_iou_score: 0.6534 - lr: 1.0000e-04
# Epoch 29/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.1787 - iou_score: 0.6483 - val_loss: 1.2742 - val_iou_score: 0.6807 - lr: 1.0000e-04
# Epoch 30/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1811 - iou_score: 0.6489 - val_loss: 1.2906 - val_iou_score: 0.6665 - lr: 1.0000e-04
# Epoch 31/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.1761 - iou_score: 0.6640 - val_loss: 1.2694 - val_iou_score: 0.6819 - lr: 1.0000e-04
# Epoch 32/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1772 - iou_score: 0.6543 - val_loss: 1.2942 - val_iou_score: 0.6636 - lr: 1.0000e-04
# Epoch 33/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1686 - iou_score: 0.6682 - val_loss: 1.3207 - val_iou_score: 0.6415 - lr: 1.0000e-04
# Epoch 34/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1591 - iou_score: 0.6723 - val_loss: 1.3080 - val_iou_score: 0.6556 - lr: 1.0000e-04
# Epoch 35/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1704 - iou_score: 0.6590 - val_loss: 1.3341 - val_iou_score: 0.6373 - lr: 1.0000e-04
# Epoch 36/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1528 - iou_score: 0.6723 - val_loss: 1.2911 - val_iou_score: 0.6667 - lr: 1.0000e-04
# Epoch 37/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1598 - iou_score: 0.6607 - val_loss: 1.2780 - val_iou_score: 0.6790 - lr: 1.0000e-04
# Epoch 38/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1591 - iou_score: 0.6606 - val_loss: 1.6937 - val_iou_score: 0.2823 - lr: 1.0000e-04
# Epoch 39/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1460 - iou_score: 0.6694 - val_loss: 1.2850 - val_iou_score: 0.6665 - lr: 1.0000e-04
# Epoch 40/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1546 - iou_score: 0.6706 - val_loss: 1.3077 - val_iou_score: 0.6544 - lr: 1.0000e-04
# Epoch 41/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1359 - iou_score: 0.6740 - val_loss: 1.3095 - val_iou_score: 0.6509 - lr: 1.0000e-04
# Epoch 42/500
# 461/461 [==============================] - 56s 120ms/step - loss: 1.1187 - iou_score: 0.6946 - val_loss: 1.2629 - val_iou_score: 0.6874 - lr: 1.0000e-05
# Epoch 43/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1078 - iou_score: 0.7112 - val_loss: 1.2639 - val_iou_score: 0.6869 - lr: 1.0000e-05
# Epoch 44/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.1112 - iou_score: 0.7103 - val_loss: 1.2628 - val_iou_score: 0.6876 - lr: 1.0000e-05
# Epoch 45/500
# 461/461 [==============================] - 56s 120ms/step - loss: 1.1043 - iou_score: 0.7087 - val_loss: 1.2554 - val_iou_score: 0.6934 - lr: 1.0000e-05
# Epoch 46/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1065 - iou_score: 0.7104 - val_loss: 1.2619 - val_iou_score: 0.6883 - lr: 1.0000e-05
# Epoch 47/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0927 - iou_score: 0.7179 - val_loss: 1.2601 - val_iou_score: 0.6896 - lr: 1.0000e-05
# Epoch 48/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1037 - iou_score: 0.7228 - val_loss: 1.2704 - val_iou_score: 0.6819 - lr: 1.0000e-05
# Epoch 49/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0969 - iou_score: 0.7263 - val_loss: 1.2596 - val_iou_score: 0.6902 - lr: 1.0000e-05
# Epoch 50/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0903 - iou_score: 0.7250 - val_loss: 1.2611 - val_iou_score: 0.6895 - lr: 1.0000e-05
# Epoch 51/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0900 - iou_score: 0.7214 - val_loss: 1.2556 - val_iou_score: 0.6934 - lr: 1.0000e-05
# Epoch 52/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0959 - iou_score: 0.7271 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-05
# Epoch 53/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0928 - iou_score: 0.7315 - val_loss: 1.2636 - val_iou_score: 0.6871 - lr: 1.0000e-05
# Epoch 54/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0873 - iou_score: 0.7204 - val_loss: 1.2583 - val_iou_score: 0.6909 - lr: 1.0000e-05
# Epoch 55/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0886 - iou_score: 0.7235 - val_loss: 1.2615 - val_iou_score: 0.6886 - lr: 1.0000e-05
# Epoch 56/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0728 - iou_score: 0.7307 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-06
# Epoch 57/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0819 - iou_score: 0.7346 - val_loss: 1.2612 - val_iou_score: 0.6888 - lr: 1.0000e-06
# Epoch 58/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0924 - iou_score: 0.7372 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 1.0000e-06
# Epoch 59/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0935 - iou_score: 0.7342 - val_loss: 1.2577 - val_iou_score: 0.6918 - lr: 1.0000e-06
# Epoch 60/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0932 - iou_score: 0.7390 - val_loss: 1.2566 - val_iou_score: 0.6924 - lr: 1.0000e-06
# Epoch 61/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0902 - iou_score: 0.7354 - val_loss: 1.2574 - val_iou_score: 0.6919 - lr: 1.0000e-06
# Epoch 62/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0843 - iou_score: 0.7275 - val_loss: 1.2575 - val_iou_score: 0.6920 - lr: 1.0000e-06
# Epoch 63/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0795 - iou_score: 0.7282 - val_loss: 1.2590 - val_iou_score: 0.6905 - lr: 1.0000e-06
# Epoch 64/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0780 - iou_score: 0.7313 - val_loss: 1.2582 - val_iou_score: 0.6914 - lr: 1.0000e-06
# Epoch 65/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0755 - iou_score: 0.7314 - val_loss: 1.2591 - val_iou_score: 0.6906 - lr: 1.0000e-06
# Epoch 66/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0896 - iou_score: 0.7277 - val_loss: 1.2569 - val_iou_score: 0.6923 - lr: 1.0000e-07
# Epoch 67/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0853 - iou_score: 0.7268 - val_loss: 1.2580 - val_iou_score: 0.6916 - lr: 1.0000e-07
# Epoch 68/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0832 - iou_score: 0.7464 - val_loss: 1.2571 - val_iou_score: 0.6923 - lr: 1.0000e-07
# Epoch 69/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0883 - iou_score: 0.7351 - val_loss: 1.2583 - val_iou_score: 0.6913 - lr: 1.0000e-07
# Epoch 70/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0835 - iou_score: 0.7373 - val_loss: 1.2602 - val_iou_score: 0.6896 - lr: 1.0000e-07
# Epoch 71/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0834 - iou_score: 0.7297 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 1.0000e-07
# Epoch 72/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0837 - iou_score: 0.7290 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-07
# Epoch 73/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0814 - iou_score: 0.7273 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 1.0000e-07
# Epoch 74/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0866 - iou_score: 0.7407 - val_loss: 1.2574 - val_iou_score: 0.6920 - lr: 1.0000e-07
# Epoch 75/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0870 - iou_score: 0.7256 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 1.0000e-07
# Epoch 76/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0867 - iou_score: 0.7331 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 1.0000e-08
# Epoch 77/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0775 - iou_score: 0.7403 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0000e-08
# Epoch 78/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0768 - iou_score: 0.7305 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-08
# Epoch 79/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0735 - iou_score: 0.7317 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-08
# Epoch 80/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0805 - iou_score: 0.7286 - val_loss: 1.2567 - val_iou_score: 0.6925 - lr: 1.0000e-08
# Epoch 81/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0883 - iou_score: 0.7306 - val_loss: 1.2592 - val_iou_score: 0.6905 - lr: 1.0000e-08
# Epoch 82/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0816 - iou_score: 0.7283 - val_loss: 1.2569 - val_iou_score: 0.6924 - lr: 1.0000e-08
# Epoch 83/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0790 - iou_score: 0.7306 - val_loss: 1.2585 - val_iou_score: 0.6912 - lr: 1.0000e-08
# Epoch 84/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0757 - iou_score: 0.7332 - val_loss: 1.2575 - val_iou_score: 0.6921 - lr: 1.0000e-08
# Epoch 85/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0804 - iou_score: 0.7346 - val_loss: 1.2580 - val_iou_score: 0.6916 - lr: 1.0000e-08
# Epoch 86/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0720 - iou_score: 0.7394 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 1.0000e-09
# Epoch 87/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0797 - iou_score: 0.7359 - val_loss: 1.2591 - val_iou_score: 0.6906 - lr: 1.0000e-09
# Epoch 88/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0818 - iou_score: 0.7284 - val_loss: 1.2587 - val_iou_score: 0.6909 - lr: 1.0000e-09
# Epoch 89/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0796 - iou_score: 0.7368 - val_loss: 1.2582 - val_iou_score: 0.6914 - lr: 1.0000e-09
# Epoch 90/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0785 - iou_score: 0.7300 - val_loss: 1.2570 - val_iou_score: 0.6923 - lr: 1.0000e-09
# Epoch 91/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0779 - iou_score: 0.7269 - val_loss: 1.2584 - val_iou_score: 0.6910 - lr: 1.0000e-09
# Epoch 92/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0790 - iou_score: 0.7333 - val_loss: 1.2585 - val_iou_score: 0.6911 - lr: 1.0000e-09
# Epoch 93/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0811 - iou_score: 0.7326 - val_loss: 1.2577 - val_iou_score: 0.6918 - lr: 1.0000e-09
# Epoch 94/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0872 - iou_score: 0.7370 - val_loss: 1.2595 - val_iou_score: 0.6903 - lr: 1.0000e-09
# Epoch 95/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0825 - iou_score: 0.7351 - val_loss: 1.2572 - val_iou_score: 0.6920 - lr: 1.0000e-09
# Epoch 96/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0887 - iou_score: 0.7234 - val_loss: 1.2595 - val_iou_score: 0.6903 - lr: 1.0000e-10
# Epoch 97/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0902 - iou_score: 0.7334 - val_loss: 1.2580 - val_iou_score: 0.6914 - lr: 1.0000e-10
# Epoch 98/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1008 - iou_score: 0.7345 - val_loss: 1.2575 - val_iou_score: 0.6920 - lr: 1.0000e-10
# Epoch 99/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0918 - iou_score: 0.7281 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 1.0000e-10
# Epoch 100/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0785 - iou_score: 0.7435 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-10
# Epoch 101/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0901 - iou_score: 0.7318 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 1.0000e-10
# Epoch 102/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0855 - iou_score: 0.7331 - val_loss: 1.2566 - val_iou_score: 0.6925 - lr: 1.0000e-10
# Epoch 103/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0818 - iou_score: 0.7260 - val_loss: 1.2584 - val_iou_score: 0.6909 - lr: 1.0000e-10
# Epoch 104/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0861 - iou_score: 0.7353 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 1.0000e-10
# Epoch 105/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0841 - iou_score: 0.7380 - val_loss: 1.2578 - val_iou_score: 0.6916 - lr: 1.0000e-10
# Epoch 106/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0807 - iou_score: 0.7322 - val_loss: 1.2591 - val_iou_score: 0.6904 - lr: 1.0000e-11
# Epoch 107/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0806 - iou_score: 0.7301 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 1.0000e-11
# Epoch 108/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0723 - iou_score: 0.7404 - val_loss: 1.2585 - val_iou_score: 0.6911 - lr: 1.0000e-11
# Epoch 109/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0890 - iou_score: 0.7283 - val_loss: 1.2570 - val_iou_score: 0.6923 - lr: 1.0000e-11
# Epoch 110/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0778 - iou_score: 0.7331 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-11
# Epoch 111/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0801 - iou_score: 0.7388 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-11
# Epoch 112/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0657 - iou_score: 0.7335 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0000e-11
# Epoch 113/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0976 - iou_score: 0.7214 - val_loss: 1.2591 - val_iou_score: 0.6906 - lr: 1.0000e-11
# Epoch 114/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0862 - iou_score: 0.7288 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 1.0000e-11
# Epoch 115/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0749 - iou_score: 0.7338 - val_loss: 1.2585 - val_iou_score: 0.6909 - lr: 1.0000e-11
# Epoch 116/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0791 - iou_score: 0.7272 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 1.0000e-12
# Epoch 117/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0834 - iou_score: 0.7330 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 1.0000e-12
# Epoch 118/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0832 - iou_score: 0.7370 - val_loss: 1.2587 - val_iou_score: 0.6909 - lr: 1.0000e-12
# Epoch 119/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0786 - iou_score: 0.7358 - val_loss: 1.2574 - val_iou_score: 0.6920 - lr: 1.0000e-12
# Epoch 120/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0873 - iou_score: 0.7303 - val_loss: 1.2571 - val_iou_score: 0.6922 - lr: 1.0000e-12
# Epoch 121/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0792 - iou_score: 0.7349 - val_loss: 1.2582 - val_iou_score: 0.6914 - lr: 1.0000e-12
# Epoch 122/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0891 - iou_score: 0.7369 - val_loss: 1.2578 - val_iou_score: 0.6916 - lr: 1.0000e-12
# Epoch 123/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0750 - iou_score: 0.7271 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-12
# Epoch 124/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0843 - iou_score: 0.7287 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 1.0000e-12
# Epoch 125/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0925 - iou_score: 0.7283 - val_loss: 1.2592 - val_iou_score: 0.6904 - lr: 1.0000e-12
# Epoch 126/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0895 - iou_score: 0.7350 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-13
# Epoch 127/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0920 - iou_score: 0.7385 - val_loss: 1.2574 - val_iou_score: 0.6920 - lr: 1.0000e-13
# Epoch 128/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0869 - iou_score: 0.7255 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 1.0000e-13
# Epoch 129/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0890 - iou_score: 0.7251 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-13
# Epoch 130/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0815 - iou_score: 0.7369 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 1.0000e-13
# Epoch 131/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0752 - iou_score: 0.7268 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-13
# Epoch 132/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0829 - iou_score: 0.7312 - val_loss: 1.2590 - val_iou_score: 0.6907 - lr: 1.0000e-13
# Epoch 133/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0865 - iou_score: 0.7338 - val_loss: 1.2579 - val_iou_score: 0.6917 - lr: 1.0000e-13
# Epoch 134/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0914 - iou_score: 0.7330 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 1.0000e-13
# Epoch 135/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0834 - iou_score: 0.7308 - val_loss: 1.2585 - val_iou_score: 0.6909 - lr: 1.0000e-13
# Epoch 136/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0821 - iou_score: 0.7296 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-14
# Epoch 137/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0970 - iou_score: 0.7316 - val_loss: 1.2591 - val_iou_score: 0.6907 - lr: 1.0000e-14
# Epoch 138/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0919 - iou_score: 0.7343 - val_loss: 1.2582 - val_iou_score: 0.6912 - lr: 1.0000e-14
# Epoch 139/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0841 - iou_score: 0.7341 - val_loss: 1.2567 - val_iou_score: 0.6925 - lr: 1.0000e-14
# Epoch 140/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0710 - iou_score: 0.7370 - val_loss: 1.2587 - val_iou_score: 0.6908 - lr: 1.0000e-14
# Epoch 141/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0659 - iou_score: 0.7396 - val_loss: 1.2580 - val_iou_score: 0.6914 - lr: 1.0000e-14
# Epoch 142/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0701 - iou_score: 0.7284 - val_loss: 1.2585 - val_iou_score: 0.6912 - lr: 1.0000e-14
# Epoch 143/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0755 - iou_score: 0.7301 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 1.0000e-14
# Epoch 144/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0808 - iou_score: 0.7287 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-14
# Epoch 145/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0768 - iou_score: 0.7385 - val_loss: 1.2596 - val_iou_score: 0.6903 - lr: 1.0000e-14
# Epoch 146/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0787 - iou_score: 0.7306 - val_loss: 1.2575 - val_iou_score: 0.6918 - lr: 1.0000e-15
# Epoch 147/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0774 - iou_score: 0.7307 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-15
# Epoch 148/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0842 - iou_score: 0.7301 - val_loss: 1.2576 - val_iou_score: 0.6917 - lr: 1.0000e-15
# Epoch 149/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0830 - iou_score: 0.7288 - val_loss: 1.2590 - val_iou_score: 0.6905 - lr: 1.0000e-15
# Epoch 150/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0887 - iou_score: 0.7377 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0000e-15
# Epoch 151/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0791 - iou_score: 0.7298 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 1.0000e-15
# Epoch 152/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0969 - iou_score: 0.7279 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0000e-15
# Epoch 153/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0860 - iou_score: 0.7311 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 1.0000e-15
# Epoch 154/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0935 - iou_score: 0.7331 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 1.0000e-15
# Epoch 155/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0823 - iou_score: 0.7383 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-15
# Epoch 156/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0876 - iou_score: 0.7342 - val_loss: 1.2580 - val_iou_score: 0.6913 - lr: 1.0000e-16
# Epoch 157/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0978 - iou_score: 0.7237 - val_loss: 1.2569 - val_iou_score: 0.6924 - lr: 1.0000e-16
# Epoch 158/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0838 - iou_score: 0.7297 - val_loss: 1.2576 - val_iou_score: 0.6917 - lr: 1.0000e-16
# Epoch 159/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0820 - iou_score: 0.7313 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 1.0000e-16
# Epoch 160/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0859 - iou_score: 0.7389 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-16
# Epoch 161/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0816 - iou_score: 0.7321 - val_loss: 1.2578 - val_iou_score: 0.6917 - lr: 1.0000e-16
# Epoch 162/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0837 - iou_score: 0.7361 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-16
# Epoch 163/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0896 - iou_score: 0.7371 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-16
# Epoch 164/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0871 - iou_score: 0.7378 - val_loss: 1.2574 - val_iou_score: 0.6919 - lr: 1.0000e-16
# Epoch 165/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0767 - iou_score: 0.7379 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 1.0000e-16
# Epoch 166/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0823 - iou_score: 0.7317 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-17
# Epoch 167/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0898 - iou_score: 0.7317 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-17
# Epoch 168/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0792 - iou_score: 0.7341 - val_loss: 1.2583 - val_iou_score: 0.6913 - lr: 1.0000e-17
# Epoch 169/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0866 - iou_score: 0.7372 - val_loss: 1.2574 - val_iou_score: 0.6921 - lr: 1.0000e-17
# Epoch 170/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0831 - iou_score: 0.7353 - val_loss: 1.2585 - val_iou_score: 0.6908 - lr: 1.0000e-17
# Epoch 171/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0862 - iou_score: 0.7381 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-17
# Epoch 172/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0842 - iou_score: 0.7367 - val_loss: 1.2571 - val_iou_score: 0.6922 - lr: 1.0000e-17
# Epoch 173/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0983 - iou_score: 0.7232 - val_loss: 1.2585 - val_iou_score: 0.6909 - lr: 1.0000e-17
# Epoch 174/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0670 - iou_score: 0.7416 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 1.0000e-17
# Epoch 175/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0884 - iou_score: 0.7344 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 1.0000e-17
# Epoch 176/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0889 - iou_score: 0.7363 - val_loss: 1.2577 - val_iou_score: 0.6916 - lr: 1.0000e-18
# Epoch 177/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0929 - iou_score: 0.7347 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-18
# Epoch 178/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.1035 - iou_score: 0.7221 - val_loss: 1.2602 - val_iou_score: 0.6897 - lr: 1.0000e-18
# Epoch 179/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0789 - iou_score: 0.7360 - val_loss: 1.2572 - val_iou_score: 0.6922 - lr: 1.0000e-18
# Epoch 180/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0743 - iou_score: 0.7363 - val_loss: 1.2581 - val_iou_score: 0.6913 - lr: 1.0000e-18
# Epoch 181/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0874 - iou_score: 0.7293 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-18
# Epoch 182/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0872 - iou_score: 0.7418 - val_loss: 1.2577 - val_iou_score: 0.6916 - lr: 1.0000e-18
# Epoch 183/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0795 - iou_score: 0.7301 - val_loss: 1.2575 - val_iou_score: 0.6918 - lr: 1.0000e-18
# Epoch 184/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0831 - iou_score: 0.7366 - val_loss: 1.2570 - val_iou_score: 0.6923 - lr: 1.0000e-18
# Epoch 185/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0803 - iou_score: 0.7331 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 1.0000e-18
# Epoch 186/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0824 - iou_score: 0.7342 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 1.0000e-19
# Epoch 187/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0834 - iou_score: 0.7337 - val_loss: 1.2577 - val_iou_score: 0.6917 - lr: 1.0000e-19
# Epoch 188/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0723 - iou_score: 0.7309 - val_loss: 1.2561 - val_iou_score: 0.6930 - lr: 1.0000e-19
# Epoch 189/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0868 - iou_score: 0.7340 - val_loss: 1.2574 - val_iou_score: 0.6921 - lr: 1.0000e-19
# Epoch 190/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0809 - iou_score: 0.7371 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 1.0000e-19
# Epoch 191/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0884 - iou_score: 0.7346 - val_loss: 1.2564 - val_iou_score: 0.6928 - lr: 1.0000e-19
# Epoch 192/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0738 - iou_score: 0.7318 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 1.0000e-19
# Epoch 193/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0822 - iou_score: 0.7269 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 1.0000e-19
# Epoch 194/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0822 - iou_score: 0.7372 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-19
# Epoch 195/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0924 - iou_score: 0.7393 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-19
# Epoch 196/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0802 - iou_score: 0.7356 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 1.0000e-20
# Epoch 197/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0679 - iou_score: 0.7241 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 1.0000e-20
# Epoch 198/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0734 - iou_score: 0.7383 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 1.0000e-20
# Epoch 199/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0823 - iou_score: 0.7282 - val_loss: 1.2571 - val_iou_score: 0.6921 - lr: 1.0000e-20
# Epoch 200/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0807 - iou_score: 0.7361 - val_loss: 1.2586 - val_iou_score: 0.6908 - lr: 1.0000e-20
# Epoch 201/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0880 - iou_score: 0.7334 - val_loss: 1.2587 - val_iou_score: 0.6910 - lr: 1.0000e-20
# Epoch 202/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0720 - iou_score: 0.7424 - val_loss: 1.2588 - val_iou_score: 0.6908 - lr: 1.0000e-20
# Epoch 203/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0753 - iou_score: 0.7309 - val_loss: 1.2589 - val_iou_score: 0.6908 - lr: 1.0000e-20
# Epoch 204/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0757 - iou_score: 0.7301 - val_loss: 1.2566 - val_iou_score: 0.6926 - lr: 1.0000e-20
# Epoch 205/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0908 - iou_score: 0.7246 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 1.0000e-20
# Epoch 206/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0900 - iou_score: 0.7358 - val_loss: 1.2590 - val_iou_score: 0.6907 - lr: 1.0000e-21
# Epoch 207/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0886 - iou_score: 0.7394 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-21
# Epoch 208/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0795 - iou_score: 0.7391 - val_loss: 1.2577 - val_iou_score: 0.6917 - lr: 1.0000e-21
# Epoch 209/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0851 - iou_score: 0.7268 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-21
# Epoch 210/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0780 - iou_score: 0.7348 - val_loss: 1.2588 - val_iou_score: 0.6908 - lr: 1.0000e-21
# Epoch 211/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0869 - iou_score: 0.7356 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 1.0000e-21
# Epoch 212/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0772 - iou_score: 0.7252 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0000e-21
# Epoch 213/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0786 - iou_score: 0.7301 - val_loss: 1.2596 - val_iou_score: 0.6901 - lr: 1.0000e-21
# Epoch 214/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0710 - iou_score: 0.7281 - val_loss: 1.2570 - val_iou_score: 0.6923 - lr: 1.0000e-21
# Epoch 215/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0735 - iou_score: 0.7370 - val_loss: 1.2590 - val_iou_score: 0.6907 - lr: 1.0000e-21
# Epoch 216/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0750 - iou_score: 0.7369 - val_loss: 1.2596 - val_iou_score: 0.6900 - lr: 1.0000e-22
# Epoch 217/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0673 - iou_score: 0.7303 - val_loss: 1.2596 - val_iou_score: 0.6902 - lr: 1.0000e-22
# Epoch 218/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0890 - iou_score: 0.7338 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-22
# Epoch 219/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0843 - iou_score: 0.7286 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-22
# Epoch 220/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0873 - iou_score: 0.7363 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.0000e-22
# Epoch 221/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0755 - iou_score: 0.7289 - val_loss: 1.2580 - val_iou_score: 0.6916 - lr: 1.0000e-22
# Epoch 222/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0761 - iou_score: 0.7406 - val_loss: 1.2577 - val_iou_score: 0.6916 - lr: 1.0000e-22
# Epoch 223/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0680 - iou_score: 0.7351 - val_loss: 1.2569 - val_iou_score: 0.6923 - lr: 1.0000e-22
# Epoch 224/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0886 - iou_score: 0.7380 - val_loss: 1.2589 - val_iou_score: 0.6907 - lr: 1.0000e-22
# Epoch 225/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0839 - iou_score: 0.7308 - val_loss: 1.2577 - val_iou_score: 0.6918 - lr: 1.0000e-22
# Epoch 226/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0797 - iou_score: 0.7361 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-23
# Epoch 227/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0835 - iou_score: 0.7343 - val_loss: 1.2580 - val_iou_score: 0.6916 - lr: 1.0000e-23
# Epoch 228/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0857 - iou_score: 0.7234 - val_loss: 1.2593 - val_iou_score: 0.6904 - lr: 1.0000e-23
# Epoch 229/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0818 - iou_score: 0.7370 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 1.0000e-23
# Epoch 230/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0729 - iou_score: 0.7363 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-23
# Epoch 231/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0766 - iou_score: 0.7236 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 1.0000e-23
# Epoch 232/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0907 - iou_score: 0.7458 - val_loss: 1.2575 - val_iou_score: 0.6918 - lr: 1.0000e-23
# Epoch 233/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0825 - iou_score: 0.7336 - val_loss: 1.2597 - val_iou_score: 0.6901 - lr: 1.0000e-23
# Epoch 234/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0709 - iou_score: 0.7267 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-23
# Epoch 235/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0751 - iou_score: 0.7374 - val_loss: 1.2577 - val_iou_score: 0.6917 - lr: 1.0000e-23
# Epoch 236/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0783 - iou_score: 0.7401 - val_loss: 1.2587 - val_iou_score: 0.6908 - lr: 1.0000e-24
# Epoch 237/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0832 - iou_score: 0.7304 - val_loss: 1.2580 - val_iou_score: 0.6914 - lr: 1.0000e-24
# Epoch 238/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0777 - iou_score: 0.7336 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 1.0000e-24
# Epoch 239/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0800 - iou_score: 0.7321 - val_loss: 1.2558 - val_iou_score: 0.6934 - lr: 1.0000e-24
# Epoch 240/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0810 - iou_score: 0.7277 - val_loss: 1.2606 - val_iou_score: 0.6893 - lr: 1.0000e-24
# Epoch 241/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0874 - iou_score: 0.7352 - val_loss: 1.2575 - val_iou_score: 0.6918 - lr: 1.0000e-24
# Epoch 242/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0874 - iou_score: 0.7340 - val_loss: 1.2585 - val_iou_score: 0.6912 - lr: 1.0000e-24
# Epoch 243/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0838 - iou_score: 0.7247 - val_loss: 1.2590 - val_iou_score: 0.6908 - lr: 1.0000e-24
# Epoch 244/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0788 - iou_score: 0.7287 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 1.0000e-24
# Epoch 245/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0857 - iou_score: 0.7369 - val_loss: 1.2572 - val_iou_score: 0.6921 - lr: 1.0000e-24
# Epoch 246/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0774 - iou_score: 0.7319 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-25
# Epoch 247/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0752 - iou_score: 0.7366 - val_loss: 1.2576 - val_iou_score: 0.6917 - lr: 1.0000e-25
# Epoch 248/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0799 - iou_score: 0.7423 - val_loss: 1.2577 - val_iou_score: 0.6918 - lr: 1.0000e-25
# Epoch 249/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0815 - iou_score: 0.7336 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-25
# Epoch 250/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0895 - iou_score: 0.7352 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-25
# Epoch 251/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0783 - iou_score: 0.7292 - val_loss: 1.2589 - val_iou_score: 0.6906 - lr: 1.0000e-25
# Epoch 252/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0880 - iou_score: 0.7301 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 1.0000e-25
# Epoch 253/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0900 - iou_score: 0.7326 - val_loss: 1.2588 - val_iou_score: 0.6907 - lr: 1.0000e-25
# Epoch 254/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0735 - iou_score: 0.7361 - val_loss: 1.2583 - val_iou_score: 0.6913 - lr: 1.0000e-25
# Epoch 255/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0835 - iou_score: 0.7339 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 1.0000e-25
# Epoch 256/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0879 - iou_score: 0.7320 - val_loss: 1.2569 - val_iou_score: 0.6924 - lr: 1.0000e-26
# Epoch 257/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0794 - iou_score: 0.7295 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-26
# Epoch 258/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0909 - iou_score: 0.7338 - val_loss: 1.2594 - val_iou_score: 0.6902 - lr: 1.0000e-26
# Epoch 259/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0818 - iou_score: 0.7303 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 1.0000e-26
# Epoch 260/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0783 - iou_score: 0.7330 - val_loss: 1.2581 - val_iou_score: 0.6913 - lr: 1.0000e-26
# Epoch 261/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0794 - iou_score: 0.7398 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-26
# Epoch 262/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0846 - iou_score: 0.7345 - val_loss: 1.2577 - val_iou_score: 0.6917 - lr: 1.0000e-26
# Epoch 263/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0927 - iou_score: 0.7357 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 1.0000e-26
# Epoch 264/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0818 - iou_score: 0.7291 - val_loss: 1.2600 - val_iou_score: 0.6899 - lr: 1.0000e-26
# Epoch 265/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0899 - iou_score: 0.7305 - val_loss: 1.2560 - val_iou_score: 0.6930 - lr: 1.0000e-26
# Epoch 266/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0803 - iou_score: 0.7290 - val_loss: 1.2581 - val_iou_score: 0.6913 - lr: 1.0000e-27
# Epoch 267/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0826 - iou_score: 0.7306 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 1.0000e-27
# Epoch 268/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0875 - iou_score: 0.7239 - val_loss: 1.2580 - val_iou_score: 0.6916 - lr: 1.0000e-27
# Epoch 269/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0801 - iou_score: 0.7306 - val_loss: 1.2573 - val_iou_score: 0.6921 - lr: 1.0000e-27
# Epoch 270/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0925 - iou_score: 0.7363 - val_loss: 1.2578 - val_iou_score: 0.6917 - lr: 1.0000e-27
# Epoch 271/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0900 - iou_score: 0.7355 - val_loss: 1.2593 - val_iou_score: 0.6904 - lr: 1.0000e-27
# Epoch 272/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0711 - iou_score: 0.7340 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.0000e-27
# Epoch 273/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0731 - iou_score: 0.7289 - val_loss: 1.2592 - val_iou_score: 0.6904 - lr: 1.0000e-27
# Epoch 274/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0773 - iou_score: 0.7381 - val_loss: 1.2585 - val_iou_score: 0.6911 - lr: 1.0000e-27
# Epoch 275/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0834 - iou_score: 0.7354 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 1.0000e-27
# Epoch 276/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0753 - iou_score: 0.7429 - val_loss: 1.2595 - val_iou_score: 0.6903 - lr: 1.0000e-28
# Epoch 277/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0800 - iou_score: 0.7374 - val_loss: 1.2574 - val_iou_score: 0.6918 - lr: 1.0000e-28
# Epoch 278/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0743 - iou_score: 0.7278 - val_loss: 1.2577 - val_iou_score: 0.6916 - lr: 1.0000e-28
# Epoch 279/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0865 - iou_score: 0.7259 - val_loss: 1.2593 - val_iou_score: 0.6904 - lr: 1.0000e-28
# Epoch 280/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0749 - iou_score: 0.7282 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 1.0000e-28
# Epoch 281/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0909 - iou_score: 0.7323 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 1.0000e-28
# Epoch 282/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0751 - iou_score: 0.7364 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 1.0000e-28
# Epoch 283/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0852 - iou_score: 0.7276 - val_loss: 1.2589 - val_iou_score: 0.6906 - lr: 1.0000e-28
# Epoch 284/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0747 - iou_score: 0.7310 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0000e-28
# Epoch 285/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0912 - iou_score: 0.7315 - val_loss: 1.2590 - val_iou_score: 0.6907 - lr: 1.0000e-28
# Epoch 286/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0797 - iou_score: 0.7322 - val_loss: 1.2574 - val_iou_score: 0.6920 - lr: 1.0000e-29
# Epoch 287/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0812 - iou_score: 0.7367 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 1.0000e-29
# Epoch 288/500
# 461/461 [==============================] - 55s 120ms/step - loss: 1.0773 - iou_score: 0.7332 - val_loss: 1.2574 - val_iou_score: 0.6920 - lr: 1.0000e-29
# ...
# Epoch 406/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0800 - iou_score: 0.7348 - val_loss: 1.2570 - val_iou_score: 0.6922 - lr: 9.9997e-42
# Epoch 407/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0824 - iou_score: 0.7267 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 9.9997e-42
# Epoch 408/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0845 - iou_score: 0.7310 - val_loss: 1.2579 - val_iou_score: 0.6916 - lr: 9.9997e-42
# Epoch 409/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0813 - iou_score: 0.7349 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 9.9997e-42
# Epoch 410/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0887 - iou_score: 0.7305 - val_loss: 1.2600 - val_iou_score: 0.6899 - lr: 9.9997e-42
# Epoch 411/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0886 - iou_score: 0.7389 - val_loss: 1.2592 - val_iou_score: 0.6906 - lr: 9.9997e-42
# Epoch 412/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0842 - iou_score: 0.7262 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 9.9997e-42
# Epoch 413/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0893 - iou_score: 0.7288 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 9.9997e-42
# Epoch 414/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0780 - iou_score: 0.7364 - val_loss: 1.2578 - val_iou_score: 0.6917 - lr: 9.9997e-42
# Epoch 415/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0879 - iou_score: 0.7298 - val_loss: 1.2599 - val_iou_score: 0.6899 - lr: 9.9997e-42
# Epoch 416/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0894 - iou_score: 0.7274 - val_loss: 1.2573 - val_iou_score: 0.6921 - lr: 1.0005e-42
# Epoch 417/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0826 - iou_score: 0.7326 - val_loss: 1.2589 - val_iou_score: 0.6907 - lr: 1.0005e-42
# Epoch 418/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0785 - iou_score: 0.7340 - val_loss: 1.2589 - val_iou_score: 0.6906 - lr: 1.0005e-42
# Epoch 419/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0780 - iou_score: 0.7372 - val_loss: 1.2567 - val_iou_score: 0.6925 - lr: 1.0005e-42
# Epoch 420/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0876 - iou_score: 0.7302 - val_loss: 1.2581 - val_iou_score: 0.6913 - lr: 1.0005e-42
# Epoch 421/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0833 - iou_score: 0.7371 - val_loss: 1.2586 - val_iou_score: 0.6909 - lr: 1.0005e-42
# Epoch 422/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0794 - iou_score: 0.7377 - val_loss: 1.2578 - val_iou_score: 0.6915 - lr: 1.0005e-42
# Epoch 423/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0929 - iou_score: 0.7320 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 1.0005e-42
# Epoch 424/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0785 - iou_score: 0.7274 - val_loss: 1.2589 - val_iou_score: 0.6906 - lr: 1.0005e-42
# Epoch 425/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0730 - iou_score: 0.7283 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.0005e-42
# Epoch 426/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0860 - iou_score: 0.7249 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 9.9492e-44
# Epoch 427/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0809 - iou_score: 0.7321 - val_loss: 1.2582 - val_iou_score: 0.6912 - lr: 9.9492e-44
# Epoch 428/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0790 - iou_score: 0.7329 - val_loss: 1.2574 - val_iou_score: 0.6919 - lr: 9.9492e-44
# Epoch 429/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0932 - iou_score: 0.7366 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 9.9492e-44
# Epoch 430/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0790 - iou_score: 0.7344 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 9.9492e-44
# Epoch 431/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0798 - iou_score: 0.7370 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 9.9492e-44
# Epoch 432/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0858 - iou_score: 0.7299 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 9.9492e-44
# Epoch 433/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0831 - iou_score: 0.7376 - val_loss: 1.2582 - val_iou_score: 0.6914 - lr: 9.9492e-44
# Epoch 434/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0734 - iou_score: 0.7243 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 9.9492e-44
# Epoch 435/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0776 - iou_score: 0.7377 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 9.9492e-44
# Epoch 436/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0756 - iou_score: 0.7381 - val_loss: 1.2575 - val_iou_score: 0.6919 - lr: 9.8091e-45
# Epoch 437/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0670 - iou_score: 0.7373 - val_loss: 1.2588 - val_iou_score: 0.6909 - lr: 9.8091e-45
# Epoch 438/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0905 - iou_score: 0.7371 - val_loss: 1.2570 - val_iou_score: 0.6922 - lr: 9.8091e-45
# Epoch 439/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0812 - iou_score: 0.7262 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 9.8091e-45
# Epoch 440/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0771 - iou_score: 0.7344 - val_loss: 1.2569 - val_iou_score: 0.6925 - lr: 9.8091e-45
# Epoch 441/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0758 - iou_score: 0.7338 - val_loss: 1.2583 - val_iou_score: 0.6913 - lr: 9.8091e-45
# Epoch 442/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0956 - iou_score: 0.7270 - val_loss: 1.2577 - val_iou_score: 0.6917 - lr: 9.8091e-45
# Epoch 443/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0719 - iou_score: 0.7362 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 9.8091e-45
# Epoch 444/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0849 - iou_score: 0.7408 - val_loss: 1.2585 - val_iou_score: 0.6910 - lr: 9.8091e-45
# Epoch 445/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0827 - iou_score: 0.7349 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 9.8091e-45
# Epoch 446/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0869 - iou_score: 0.7314 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 1.4013e-45
# Epoch 447/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0707 - iou_score: 0.7304 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 1.4013e-45
# Epoch 448/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0775 - iou_score: 0.7302 - val_loss: 1.2573 - val_iou_score: 0.6921 - lr: 1.4013e-45
# Epoch 449/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0851 - iou_score: 0.7329 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 1.4013e-45
# Epoch 450/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0799 - iou_score: 0.7370 - val_loss: 1.2566 - val_iou_score: 0.6926 - lr: 1.4013e-45
# Epoch 451/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0799 - iou_score: 0.7310 - val_loss: 1.2591 - val_iou_score: 0.6905 - lr: 1.4013e-45
# Epoch 452/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0815 - iou_score: 0.7285 - val_loss: 1.2583 - val_iou_score: 0.6911 - lr: 1.4013e-45
# Epoch 453/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0791 - iou_score: 0.7371 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 1.4013e-45
# Epoch 454/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0851 - iou_score: 0.7259 - val_loss: 1.2582 - val_iou_score: 0.6912 - lr: 1.4013e-45
# Epoch 455/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0873 - iou_score: 0.7383 - val_loss: 1.2590 - val_iou_score: 0.6907 - lr: 1.4013e-45
# Epoch 456/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0841 - iou_score: 0.7312 - val_loss: 1.2569 - val_iou_score: 0.6924 - lr: 0.0000e+00
# Epoch 457/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0843 - iou_score: 0.7331 - val_loss: 1.2569 - val_iou_score: 0.6924 - lr: 0.0000e+00
# Epoch 458/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0844 - iou_score: 0.7347 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 0.0000e+00
# Epoch 459/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0839 - iou_score: 0.7318 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 0.0000e+00
# Epoch 460/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0777 - iou_score: 0.7287 - val_loss: 1.2573 - val_iou_score: 0.6920 - lr: 0.0000e+00
# Epoch 461/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0818 - iou_score: 0.7367 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 0.0000e+00
# Epoch 462/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0798 - iou_score: 0.7226 - val_loss: 1.2573 - val_iou_score: 0.6921 - lr: 0.0000e+00
# Epoch 463/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0760 - iou_score: 0.7290 - val_loss: 1.2589 - val_iou_score: 0.6907 - lr: 0.0000e+00
# Epoch 464/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0918 - iou_score: 0.7199 - val_loss: 1.2567 - val_iou_score: 0.6925 - lr: 0.0000e+00
# Epoch 465/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0810 - iou_score: 0.7323 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 0.0000e+00
# Epoch 466/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0848 - iou_score: 0.7380 - val_loss: 1.2576 - val_iou_score: 0.6917 - lr: 0.0000e+00
# Epoch 467/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0807 - iou_score: 0.7293 - val_loss: 1.2581 - val_iou_score: 0.6913 - lr: 0.0000e+00
# Epoch 468/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0849 - iou_score: 0.7314 - val_loss: 1.2587 - val_iou_score: 0.6908 - lr: 0.0000e+00
# Epoch 469/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0848 - iou_score: 0.7377 - val_loss: 1.2578 - val_iou_score: 0.6917 - lr: 0.0000e+00
# Epoch 470/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0782 - iou_score: 0.7320 - val_loss: 1.2587 - val_iou_score: 0.6909 - lr: 0.0000e+00
# Epoch 471/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0795 - iou_score: 0.7298 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 0.0000e+00
# Epoch 472/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0851 - iou_score: 0.7377 - val_loss: 1.2580 - val_iou_score: 0.6915 - lr: 0.0000e+00
# Epoch 473/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0796 - iou_score: 0.7351 - val_loss: 1.2581 - val_iou_score: 0.6914 - lr: 0.0000e+00
# Epoch 474/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0772 - iou_score: 0.7279 - val_loss: 1.2576 - val_iou_score: 0.6918 - lr: 0.0000e+00
# Epoch 475/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0826 - iou_score: 0.7241 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 0.0000e+00
# Epoch 476/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0813 - iou_score: 0.7403 - val_loss: 1.2594 - val_iou_score: 0.6903 - lr: 0.0000e+00
# Epoch 477/500
# 461/461 [==============================] - 54s 118ms/step - loss: 1.0712 - iou_score: 0.7316 - val_loss: 1.2579 - val_iou_score: 0.6915 - lr: 0.0000e+00
# Epoch 478/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0868 - iou_score: 0.7266 - val_loss: 1.2583 - val_iou_score: 0.6912 - lr: 0.0000e+00
# Epoch 479/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0807 - iou_score: 0.7280 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 0.0000e+00
# Epoch 480/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0846 - iou_score: 0.7304 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 0.0000e+00
# Epoch 481/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0756 - iou_score: 0.7292 - val_loss: 1.2580 - val_iou_score: 0.6914 - lr: 0.0000e+00
# Epoch 482/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0825 - iou_score: 0.7394 - val_loss: 1.2591 - val_iou_score: 0.6904 - lr: 0.0000e+00
# Epoch 483/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0793 - iou_score: 0.7305 - val_loss: 1.2586 - val_iou_score: 0.6911 - lr: 0.0000e+00
# Epoch 484/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0887 - iou_score: 0.7323 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 0.0000e+00
# Epoch 485/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0839 - iou_score: 0.7351 - val_loss: 1.2580 - val_iou_score: 0.6914 - lr: 0.0000e+00
# Epoch 486/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0808 - iou_score: 0.7299 - val_loss: 1.2582 - val_iou_score: 0.6914 - lr: 0.0000e+00
# Epoch 487/500
# 461/461 [==============================] - 55s 118ms/step - loss: 1.0780 - iou_score: 0.7305 - val_loss: 1.2575 - val_iou_score: 0.6918 - lr: 0.0000e+00
# Epoch 488/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0847 - iou_score: 0.7324 - val_loss: 1.2568 - val_iou_score: 0.6926 - lr: 0.0000e+00
# Epoch 489/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0769 - iou_score: 0.7276 - val_loss: 1.2582 - val_iou_score: 0.6913 - lr: 0.0000e+00
# Epoch 490/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0759 - iou_score: 0.7322 - val_loss: 1.2565 - val_iou_score: 0.6927 - lr: 0.0000e+00
# Epoch 491/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0878 - iou_score: 0.7255 - val_loss: 1.2590 - val_iou_score: 0.6905 - lr: 0.0000e+00
# Epoch 492/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0999 - iou_score: 0.7288 - val_loss: 1.2573 - val_iou_score: 0.6921 - lr: 0.0000e+00
# Epoch 493/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0841 - iou_score: 0.7209 - val_loss: 1.2596 - val_iou_score: 0.6903 - lr: 0.0000e+00
# Epoch 494/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0872 - iou_score: 0.7325 - val_loss: 1.2584 - val_iou_score: 0.6911 - lr: 0.0000e+00
# Epoch 495/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0830 - iou_score: 0.7273 - val_loss: 1.2590 - val_iou_score: 0.6906 - lr: 0.0000e+00
# Epoch 496/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0878 - iou_score: 0.7365 - val_loss: 1.2574 - val_iou_score: 0.6921 - lr: 0.0000e+00
# Epoch 497/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0791 - iou_score: 0.7372 - val_loss: 1.2585 - val_iou_score: 0.6911 - lr: 0.0000e+00
# Epoch 498/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0747 - iou_score: 0.7351 - val_loss: 1.2569 - val_iou_score: 0.6923 - lr: 0.0000e+00
# Epoch 499/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0866 - iou_score: 0.7301 - val_loss: 1.2586 - val_iou_score: 0.6910 - lr: 0.0000e+00
# Epoch 500/500
# 461/461 [==============================] - 55s 119ms/step - loss: 1.0830 - iou_score: 0.7324 - val_loss: 1.2584 - val_iou_score: 0.6912 - lr: 0.0000e+00

# %% [markdown]
# # evaluation
# you coudl restart the kernal

# %%
import pandas as pd
from matplotlib import pyplot as plt

# 读取 CSV 文件
history_df = pd.read_csv('./history_au.csv')

# 查看数据结构
print(history_df.head())

# 绘制训练和验证损失
loss = history_df['loss']
val_loss = history_df['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('./loss_plot.png', bbox_inches='tight')  # Save the plot as PNG image
plt.show()

# 绘制训练和验证 IOU
iou = history_df['iou_score']
val_iou = history_df['val_iou_score']
plt.plot(epochs, iou, 'y', label='Training IOU')
plt.plot(epochs, val_iou, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.savefig('./iou_plot.png', bbox_inches='tight')  # Save the plot as PNG image
plt.show()
# Out:
#    epoch  iou_score      loss  val_iou_score  val_loss
# 0      0   0.516524  0.874117       0.543803  0.858128
# 1      1   0.563098  0.845399       0.563565  0.840985
# 2      2   0.576101  0.828242       0.581308  0.820235
# 3      3   0.583522  0.814971       0.585522  0.808931
# 4      4   0.592286  0.803876       0.591929  0.798005

# %%
import tensorflow as tf
import keras
print(tf.test.is_built_with_cuda())
print(tf.__version__)
print(keras.__version__)

# Make sure the GPU is available.
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name == '':
    print('GPU device not found. TensorFlow is using CPU.')
else:
    print('Found GPU at: {}'.format(device_name))


print(tf.test.is_gpu_available())
tf.config.list_physical_devices('GPU')

import segmentation_models_3D as sm
from skimage import io
from patchify import patchify, unpatchify
import numpy as np
from matplotlib import pyplot as plt
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import file_utilities as fu
# Out:
# True
# 2.10.0
# 2.10.0
# Found GPU at: /device:GPU:0
# WARNING:tensorflow:From C:\Users\Ding-Yang\AppData\Local\Temp\ipykernel_39848\68065243.py:18: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# Segmentation Models: using `keras` framework.

# %%
import numpy as np
train_img = np.load('./train_img.npy')
train_mask = np.load('./train_mask.npy')

train_mask.shape
# Out:
# (1024, 32, 64, 64, 1)

# %%
n_classes=3# background, border, axons
from keras.utils import to_categorical

train_mask_cat = to_categorical(train_mask, num_classes=n_classes)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_img, train_mask_cat, test_size = 0.20, random_state = 0)

# %%
X_train = np.load('./X_train.npy')
X_test = np.load('./X_test.npy')
y_train = np.load('./y_train.npy')
y_test = np.load('./y_test.npy')

# %%
#Define parameters for our model.
BACKBONE = 'vgg16'  #Try vgg16, efficientnetb7, inceptionv3, resnet50
LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)

dice_loss = sm.losses.DiceLoss(class_weights=np.array([0.333, 0.333, 0.333])) #优点：对于不平衡的数据集和像素级别的分割任务效果较好，能够更好地处理类别间的不平衡。缺点：对噪声敏感，容易受到边缘效应的影响。
focal_loss = sm.losses.CategoricalFocalLoss()#优点：能够解决类别不平衡问题，通过调节alpha和gamma参数可以进一步调整损失函数的重点。缺点：需要调节额外的参数，可能需要进行一定的调参工作。
jaccard_loss = sm.losses.JaccardLoss() #优点：度量了预测和标签之间的相似度，对于不平衡的数据集效果较好。缺点：对于像素级别的分割任务可能存在不连续性，需要额外处理。

total_loss = dice_loss + (1 * focal_loss) + jaccard_loss
metrics = [sm.metrics.IOUScore(threshold=0.5)]


from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights = False)
model_checkpoint = ModelCheckpoint('./best_model.h5', monitor='val_loss', save_best_only=True)

callbacks=[early_stopping, model_checkpoint,
                  CSVLogger('./history_au.csv'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20)
          ]

# %%
#Preprocess input data - otherwise you end up with garbage resutls 
# and potentially model that does not converge.

preprocess_input = sm.get_preprocessing(BACKBONE)


X_train_prep = preprocess_input(X_train)
X_test_prep = preprocess_input(X_test)

# %%
#Load the pretrained model for testing and predictions. 
from keras.models import load_model
def dice_loss_plus_1focal_loss_plus_jaccard_loss(y_true, y_pred):
    total_loss
    pass
def iou_score(y_true, y_pred):
    metrics    
    pass
model = load_model('./best_model.h5',custom_objects={'dice_loss_plus_1focal_loss_plus_jaccard_loss': dice_loss_plus_1focal_loss_plus_jaccard_loss, 'iou_score': iou_score})
model.compile(optimizer=optim, loss=total_loss, metrics=metrics)

#If you load a different model do not forget to preprocess accordingly.

# %%
from keras.models import load_model
#Load the pretrained model for testing and predictions. 
model = load_model('./best_model.h5',compile = False)

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from keras.metrics import MeanIoU
import numpy as np


# 假設 predictions 是模型的預測結果
predictions = model.predict(X_test_prep)
predictions = np.argmax(predictions, axis=-1)  # 從概率到類別索引

# 真實標籤需要與預測相同的處理
true_labels = np.argmax(y_test, axis=-1)
plt.figure(figsize=(8, 6))
# 混淆矩陣
class_labels = ['background', 'axons', 'border']
cm = confusion_matrix(true_labels.flatten(), predictions.flatten(), normalize="true")
print(cm)
ConfusionMatrixDisplay(cm, display_labels = class_labels).plot(
    include_values=True, cmap=plt.cm.Blues, xticks_rotation="vertical"
)
plt.title("Confusion Matrix")
plt.savefig('./confusion_matrix.png', bbox_inches='tight')  # Save the plot as PNG image
plt.tight_layout()
plt.show()

# 分類報告
print(classification_report(true_labels.flatten(), predictions.flatten()))

# 計算IoU
num_classes = len(np.unique(true_labels))  # 假設的類別數量
iou = MeanIoU(num_classes=num_classes)
iou.update_state(true_labels, predictions)
print("IoU:", iou.result().numpy())
# Out:
# 7/7 [==============================] - 18s 2s/step
# [[0.98593642 0.00687866 0.00718492]
#  [0.06428356 0.8507551  0.08496134]
#  [0.22136796 0.12807615 0.65055588]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99  25716502
#            1       0.71      0.85      0.78    692821
#            2       0.55      0.65      0.60    460437
#
#     accuracy                           0.98  26869760
#    macro avg       0.75      0.83      0.79  26869760
# weighted avg       0.98      0.98      0.98  26869760
#
# IoU: 0.67690855

# %%
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=4)
y_test_argmax = np.argmax(y_test, axis=4)
# Out:
# 7/7 [==============================] - 14s 2s/step

# %%
print(y_pred_argmax.shape)
print(y_test_argmax.shape)
print(np.unique(y_pred_argmax))
# Out:
# (205, 32, 64, 64)
# (205, 32, 64, 64)
# [0 1 2]

# %%
#Test some random images
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]

test_img_input=np.expand_dims(test_img, 0)
#test_img_input1 = preprocess_input(test_img_input)

test_pred1 = model.predict(test_img_input)
test_prediction1 = np.argmax(test_pred1, axis=4)[0,:,:,:]
print(test_prediction1.shape)
# Out:
# 1/1 [==============================] - 0s 490ms/step
# (32, 64, 64)

# %%
ground_truth_argmax = np.argmax(ground_truth, axis=3)
print(test_img.shape)
# Out:
# (32, 64, 64, 3)

# %%
#Plot individual slices from test predictions for verification
slice = random.randint(0, test_img.shape[2])
print(slice)
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Image')
plt.imshow(test_img[:,:,slice,0], cmap='gray')
plt.subplot(232)
plt.title('GT Label')
plt.imshow(ground_truth_argmax[:,:,slice])
plt.subplot(233)
plt.title('Prediction label')
plt.imshow(test_prediction1[:,:,slice])
plt.show()
slice
# Out:
# 28
# 28
